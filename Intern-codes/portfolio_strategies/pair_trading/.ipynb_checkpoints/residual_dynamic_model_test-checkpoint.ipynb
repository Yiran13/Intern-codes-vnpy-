# %%
from datetime import datetime
from vnpy.app.portfolio_strategy import BacktestingEngine
from vnpy.trader.constant import Interval
from residualmodel_dynamic import DynamicResidualModelStrategy
# from trend_following_version1 import ATR_RSI_Strategy
# from portfolio_signals import TredningFollowingSignals
# from portfolio_masignals import MASignals
# from portfolio_macdsignals import MACDSignals


#%%
#

# %%
engine = BacktestingEngine()

engine.set_parameters(
    vt_symbols=["HC888.SHFE", 'RB888.SHFE'],
    interval=Interval.MINUTE,
    start=datetime(2019, 3, 1 ),
    end=datetime(2019, 10, 1),
    rates={"HC888.SHFE": 0.3/10000, "RB888.SHFE": 0.3/10000},
    slippages={"HC888.SHFE": 0.0005, "RB888.SHFE": 0.0005},
    sizes={"HC888.SHFE":10, "RB888.SHFE":10},
    priceticks={"HC888.SHFE":1, "RB888.SHFE":1},
    capital=1_000_000,
    collection_names={"HC888.SHFE":"HC888", "RB888.SHFE":"RB888"}

)
engine.add_strategy(DynamicResidualModelStrategy, {'x_multiplier': 1.58,'y_multiplier': 2, 'intercept': 1328})
engine.load_data()
engine.run_backtesting()
df = engine.calculate_result()
engine.calculate_statistics()
engine.show_chart()
# Out:
# 2020-05-09 15:28:28.815108	开始加载历史数据
# 2020-05-09 15:28:29.432950	HC888.SHFE加载进度：# [14%]
# 2020-05-09 15:28:29.992208	HC888.SHFE加载进度：## [28%]
# 2020-05-09 15:28:30.537781	HC888.SHFE加载进度：#### [42%]
# 2020-05-09 15:28:31.126448	HC888.SHFE加载进度：##### [56%]
# 2020-05-09 15:28:31.698383	HC888.SHFE加载进度：####### [70%]
# 2020-05-09 15:28:32.326969	HC888.SHFE加载进度：######## [84%]
# 2020-05-09 15:28:32.926148	HC888.SHFE加载进度：######### [98%]
# 2020-05-09 15:28:32.969128	HC888.SHFE加载进度：########## [100%]
# 2020-05-09 15:28:32.969128	HC888.SHFE历史数据加载完成，数据量：49770
# 2020-05-09 15:28:33.584008	RB888.SHFE加载进度：# [14%]
# 2020-05-09 15:28:34.096453	RB888.SHFE加载进度：## [28%]
# 2020-05-09 15:28:34.659523	RB888.SHFE加载进度：#### [42%]
# 2020-05-09 15:28:35.273500	RB888.SHFE加载进度：##### [56%]
# 2020-05-09 15:28:35.902989	RB888.SHFE加载进度：####### [70%]
# 2020-05-09 15:28:36.499441	RB888.SHFE加载进度：######## [84%]
# 2020-05-09 15:28:37.127044	RB888.SHFE加载进度：######### [98%]
# 2020-05-09 15:28:37.171939	RB888.SHFE加载进度：########## [100%]
# 2020-05-09 15:28:37.171939	RB888.SHFE历史数据加载完成，数据量：49770
# 2020-05-09 15:28:37.171939	所有历史数据加载完成
# 2020-05-09 15:28:37.292965	策略初始化完成
# 2020-05-09 15:28:37.292965	开始回放历史数据
# 时间2019-05-06 09:00:00 多开 多HC888.SHFE 1 手 空RB888.SHFE 1 手 价
', exchange=<Exchange.SHFE: 'SHFE'>, orderid='2', tradeid='2', direction=<Direction.SHORT: '空'>, offset=<Offset.OPEN: '开'>, price=3211.0, volume=1, time='09:01:00'),
#  'BACKTESTING.3': TradeData(gateway_name='BACKTESTING', symbol='HC888', exchange=<Exchange.SHFE: 'SHFE'>, orderid='3', tradeid='3', direction=<Direction.SHORT: '空'>, offset=<Offset.CLOSE: '平'>, price=3158.0, volume=1, time='13:51:00'),
#  'BACKTESTING.4': TradeData(gateway_name='BACKTESTING', symbol='RB888', exchange=<Exchange.SHFE: 'SHFE'>, orderid='4', tradeid='4', direction=<Direction.LONG: '多'>, offset=<Offset.CLOSE: '平'>, price=3166.0, volume=1, time='13:51:00'),
#  'BACKTESTING.5': TradeData(gateway_name='BACKTESTING', symbol='HC888', exchange=<Exchange.SHFE: 'SHFE'>, orderid='5', tradeid='5', direction=<Direction.LONG: '多'>, offset=<Offset.OPEN: '开'>, price=3407.0, volume=2, time='09:01:00'),
#  'BACKTESTING.6': TradeData(gateway_name='BACKTESTING', symbol='RB888', exchange=<Exchange.SHFE: 'SHFE'>, orderid='6', tradeid='6', direction=<Direction.SHORT: '空'>, offset=<Offset.OPEN: '开'>, price=3480.0, volume=1, time='09:01:00'),
#  'BACKTESTING.7': TradeData(gateway_name='BACKTESTING', symbol='HC888', exchange=<Exchange.SHFE: 'SHFE'>, orderid='7', tradeid='7', direction=<Direction.SHORT: '空'>, offset=<Offset.CLOSE: '平'>, price=3225.0, volume=2, time='09:01:00'),
#  'BACKTESTING.8': TradeData(gateway_name='BACKTESTING', symbol='RB888', exchange=<Exchange.SHFE: 'SHFE'>, orderid='8', tradeid='8', direction=<Direction.LONG: '多'>, offset=<Offset.CLOSE: '平'>, price=3219.0, volume=1, time='09:01:00'),
#  'BACKTESTING.9': TradeData(gateway_name='BACKTESTING', symbol='HC888', exchange=<Exchange.SHFE: 'SHFE'>, orderid='9', tradeid='9', direction=<Direction.LONG: '多'>, offset=<Offset.OPEN: '开'>, price=3213.0, volume=3, time='09:03:00'),
#  'BACKTESTING.10': TradeData(gateway_name='BACKTESTING', symbol='RB888', exchange=<Exchange.SHFE: 'SHFE'>, orderid='10', tradeid='10', direction=<Direction.SHORT: '空'>, offset=<Offset.OPEN: '开'>, price=3209.0, volume=1, time='09:03:00'),
#  'BACKTESTING.11': TradeData(gateway_name='BACKTESTING', symbol='HC888', exchange=<Exchange.SHFE: 'SHFE'>, orderid='11', tradeid='11', direction=<Direction.SHORT: '空'>, offset=<Offset.CLOSE: '平'>, price=3203.0, volume=3, time='09:30:00'),
#  'BACKTESTING.12': TradeData(gateway_name='BACKTESTING', symbol='RB888', exchange=<Exchange.SHFE: 'SHFE'>, orderid='12', tradeid='12', direction=<Direction.LONG: '多'>, offset=<Offset.CLOSE: '平'>, price=3206.0, volume=1, time='09:30:00')}

# %%
engine.limit_orders
# Out:
# {'BACKTESTING.1': OrderData(gateway_name='BACKTESTING', symbol='HC888', exchange=<Exchange.SHFE: 'SHFE'>, orderid='1', type=<OrderType.LIMIT: '限价'>, direction=<Direction.LONG: '多'>, offset=<Offset.OPEN: '开'>, price=3267.0, volume=1, traded=1, status=<Status.ALLTRADED: '全部成交'>, time=''),
#  'BACKTESTING.2': OrderData(gateway_name='BACKTESTING', symbol='RB888', exchange=<Exchange.SHFE: 'SHFE'>, orderid='2', type=<OrderType.LIMIT: '限价'>, direction=<Direction.SHORT: '空'>, offset=<Offset.OPEN: '开'>, price=3180.0, volume=1, traded=1, status=<Status.ALLTRADED: '全部成交'>, time=''),
#  'BACKTESTING.3': OrderData(gateway_name='BACKTESTING', symbol='HC888', exchange=<Exchange.SHFE: 'SHFE'>, orderid='3', type=<OrderType.LIMIT: '限价'>, direction=<Direction.SHORT: '空'>, offset=<Offset.CLOSE: '平'>, price=2999.0, volume=1, traded=1, status=<Status.ALLTRADED: '全部成交'>, time=''),
#  'BACKTESTING.4': OrderData(gateway_name='BACKTESTING', symbol='RB888', exchange=<Exchange.SHFE: 'SHFE'>, orderid='4', type=<OrderType.LIMIT: '限价'>, direction=<Direction.LONG: '多'>, offset=<Offset.CLOSE: '平'>, price=3325.0, volume=1, traded=1, status=<Status.ALLTRADED: '全部成交'>, time=''),
#  'BACKTESTING.5': OrderData(gateway_name='BACKTESTING', symbol='HC888', exchange=<Exchange.SHFE: 'SHFE'>, orderid='5', type=<OrderType.LIMIT: '限价'>, direction=<Direction.LONG: '多'>, offset=<Offset.OPEN: '开'>, price=3442.0, volume=2, traded=2, status=<Status.ALLTRADED: '全部成交'>, time=''),
#  'BACKTESTING.6': OrderData(gateway_name='BACKTESTING', symbol='RB888', exchange=<Exchange.SHFE: 'SHFE'>, orderid='6', type=<OrderType.LIMIT: '限价'>, direction=<Direction.SHORT: '空'>, offset=<Offset.OPEN: '开'>, price=3446.0, volume=1, traded=1, status=<Status.ALLTRADED: '全部成交'>, time=''),
#  'BACKTESTING.7': OrderData(gateway_name='BACKTESTING', symbol='HC888', exchange=<Exchange.SHFE: 'SHFE'>, orderid='7', type=<OrderType.LIMIT: '限价'>, direction=<Direction.SHORT: '空'>, offset=<Offset.CLOSE: '平'>, price=3064.0, volume=2, traded=2, status=<Status.ALLTRADED: '全部成交'>, time=''),
#  'BACKTESTING.8': OrderData(gateway_name='BACKTESTING', symbol='RB888', exchange=<Exchange.SHFE: 'SHFE'>, orderid='8', type=<OrderType.LIMIT: '限价'>, direction=<Direction.LONG: '多'>, offset=<Offset.CLOSE: '平'>, price=3379.0, volume=1, traded=1, status=<Status.ALLTRADED: '全部成交'>, time=''),
#  'BACKTESTING.9': OrderData(gateway_name='BACKTESTING', symbol='HC888', exchange=<Exchange.SHFE: 'SHFE'>, orderid='9', type=<OrderType.LIMIT: '限价'>, direction=<Direction.LONG: '多'>, offset=<Offset.OPEN: '开'>, price=3246.0, volume=3, traded=3, status=<Status.ALLTRADED: '全部成交'>, time=''),
#  'BACKTESTING.10': OrderData(gateway_name='BACKTESTING', symbol='RB888', exchange=<Exchange.SHFE: 'SHFE'>, orderid='10', type=<OrderType.LIMIT: '限价'>, direction=<Direction.SHORT: '空'>, offset=<Offset.OPEN: '开'>, price=3177.0, volume=1, traded=1, status=<Status.ALLTRADED: '全部成交'>, time=''),
#  'BACKTESTING.11': OrderData(gateway_name='BACKTESTING', symbol='HC888', exchange=<Exchange.SHFE: 'SHFE'>, orderid='11', type=<OrderType.LIMIT: '限价'>, direction=<Direction.SHORT: '空'>, offset=<Offset.CLOSE: '平'>, price=3042.0, volume=3, traded=3, status=<Status.ALLTRADED: '全部成交'>, time=''),
#  'BACKTESTING.12': OrderData(gateway_name='BACKTESTING', symbol='RB888', exchange=<Exchange.SHFE: 'SHFE'>, orderid='12', type=<OrderType.LIMIT: '限价'>, direction=<Direction.LONG: '多'>, offset=<Offset.CLOSE: '平'>, price=3366.0, volume=1, traded=1, status=<Status.ALLTRADED: '全部成交'>, time='')}
